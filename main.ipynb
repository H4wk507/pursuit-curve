# %%
## Dwa punkty, przestrzeń 2D
## Niech E - punkt startowy uciekającego, P - punkt startowy goniącego
## E porusza się po lini prostej, z prędkością v = const
## P porusza się w kierunku E, z prędkością w = const. Tor P to krzywa pogoni.

## v = (vx, vy)
## w = (E_x-P_x, E_y-P_y)
## Po czasie dt, położenie E będzie
## d(E, dt) = (E_x + vxdt, E_y + vydt)
## Wtedy zaktualizowany wektor prędkości P po upływie czasu dt to
## w = (E_x+vxdt-P_x, E_y+vydt-P_y)

# %%
import math

Es = [[9.0, 9.0]]
Ps = [[0.0, 0.0]]

v = (1.0, -1.0)

i = 0
while True:
    E = Es[-1][:]
    E[0] += v[0]
    E[1] += v[1]
    Es.append(E)
    P = Ps[-1][:]
    wx = E[0]-P[0]
    wy = E[1]-P[1]
    l = (wx*wx + wy*wy)**0.5
    w = (2*wx/l, 2*wy/l)
    print(P, E, w)
    if abs(P[0] - E[0]) <= abs(w[0]) and abs(P[1] - E[1]) <= abs(w[1]):
        P[0] += (E[0]-P[0])
        P[1] += (E[1]-P[1])
        Ps.append(P)
        break
    P[0] += w[0]
    P[1] += w[1]
    Ps.append(P)
    i += 1

print('----')
print(Es)
print(Ps)
# Out:
# [0.0, 0.0] [10.0, 8.0] (1.5617376188860608, 1.2493900951088486)
# [1.5617376188860608, 1.2493900951088486] [11.0, 7.0] (1.70794843031248, 1.0406306546480055)
# [3.2696860491985404, 2.290020749756854] [12.0, 6.0] (1.8406925117271107, 0.7822091007344141)
# [5.110378560925652, 3.072229850491268] [13.0, 5.0] (1.9428436710069386, 0.4747193592305696)
# [7.05322223193259, 3.546949209721838] [14.0, 4.0] (1.9957602106951575, 0.13015829365053883)
# [9.048982442627748, 3.6771075033723766] [15.0, 3.0] (1.987178440534719, -0.22610140528975584)
# [11.036160883162466, 3.4510060980826207] [16.0, 2.0] (1.9196649607625298, -0.5611474302004726)
# [12.955825843924996, 2.889858667882148] [17.0, 1.0] (1.811923515149008, -0.8467190651273072)
# [14.767749359074005, 2.0431396027548407] [18.0, 0.0] (1.6905719588277355, -1.068628303960434)
# [16.45832131790174, 0.9745112987944067] [19.0, -1.0] (1.579411826661737, -1.2269711821395952)
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML


fig, ax = plt.subplots(figsize=(8, 8))
all_x = [point[0] for point in Es] + [point[0] for point in Ps]
all_y = [point[1] for point in Es] + [point[1] for point in Ps]
ax.set_xlim(min(all_x) - 1, max(all_x) + 1)
ax.set_ylim(min(all_y) - 1, max(all_y) + 1)

line_x, = ax.plot([], [], 'bo-', label='Path X', linewidth=2, markersize=8)
line_y, = ax.plot([], [], 'ro-', label='Path Y', linewidth=2, markersize=8)
ax.legend()
ax.grid(True)

def init():
    line_x.set_data([], [])
    line_y.set_data([], [])
    return line_x, line_y

def animate(frame):
    # Update x path
    x_coords = [Es[i][0] for i in range(frame + 1)]
    y_coords = [Es[i][1] for i in range(frame + 1)]
    line_x.set_data(x_coords, y_coords)
    
    # Update y path
    x_coords_y = [Ps[i][0] for i in range(frame + 1)]
    y_coords_y = [Ps[i][1] for i in range(frame + 1)]
    line_y.set_data(x_coords_y, y_coords_y)
    
    return line_x, line_y

anim = animation.FuncAnimation(fig, animate, init_func=init,
                             frames=len(Es), interval=500, 
                             blit=False, repeat=True)

plt.close()
HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...
